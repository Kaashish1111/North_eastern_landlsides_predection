# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("NER_master_landslide_dataset_v2.csv")

# %%
df.head()
# Out:
#             source_name                                        source_link  \
# 0                 E-Pao   http://www.e-pao.net/GP.asp?src=28..210810.aug10
# 1             The Hindu  http://www.thehindu.com/news/national/other-st...
# 2             The Hindu  http://www.thehindu.com/news/national/other-st...
# 3                 E-PAO       http://e-pao.net/GP.asp?src=21..020815.aug15
# 4  www.assamtribune.com  http://www.assamtribune.com/scripts/detailsnew...
#
#    event_id           event_date  event_time  \
# 0      2164  2010-07-29 23:00:00         NaN
# 1      5122  2013-07-17 00:00:00         NaN
# 2      5123  2013-07-17 00:00:00         NaN
# 3      7370  2015-08-01 00:00:00         NaN
# 4      5084  2013-07-12 23:00:00         NaN
#
#                                          event_title  \
# 0  Chingai-Kuingai(Quingai) route (16 kms), Ching...
# 1  National Highway 29 Between Patkai Bridge And ...
# 2  National Highway 2 Near Meriema Village, 10 Km...
# ...

# %%
cols_to_drop = [
    "photo_link", "notes", "storm_name",          
    "event_import_source", "event_import_id",      
    "submitted_date", "created_date", "last_edited_date",  
]

# %%
df = df.drop(columns=[c for c in cols_to_drop if c in df.columns])

# %%
CITATION_ONLY_COLS = ["source_name", "source_link"]

# %%
df["fatality_count"] = df["fatality_count"].fillna(0)
df["injury_count"] = df["injury_count"].fillna(0)

# %%
df["location_accuracy_km"] = (
    df["location_accuracy"]
    .astype(str)
    .str.replace("km", "", case=False, regex=False)
    .str.strip()
)
df["location_accuracy_km"] = pd.to_numeric(df["location_accuracy_km"], errors="coerce")
df = df.drop(columns=["location_accuracy"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'location_accuracy'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 2
# ...

# %%
df = df.sort_values("location_accuracy_km", ascending=True).reset_index(drop=True)

# %%
rain_triggers = ["downpour", "rain", "continuous_rain", "monsoon"]
df["is_rain_triggered"] = (
    df["landslide_trigger"].astype(str).str.lower().isin(rain_triggers)
)

# %%
print("Trigger value counts (check for any non-rain triggers you should exclude):")
print(df["landslide_trigger"].value_counts(dropna=False))
# Out:
# Trigger value counts (check for any non-rain triggers you should exclude):
# landslide_trigger
# downpour           167
# rain                80
# continuous_rain     69
# monsoon             17
# unknown             15
# mining               3
# Name: count, dtype: int64

# %%
size_map = {"small": 1, "medium": 2, "large": 3}
df["landslide_size_encoded"] = df["landslide_size"].astype(str).str.lower().map(size_map)

# %%
print("\nShape after cleaning:", df.shape)
print("\nMissing values per column:")
print(df.isna().sum().sort_values(ascending=False))
print("\nRows with is_rain_triggered == False (review these manually):")
print(df.loc[~df["is_rain_triggered"], ["event_id", "landslide_trigger", "event_title"]])
# Out:
# Shape after cleaning: (351, 31)
#
# Missing values per column:
# location_accuracy_km         23
# landslide_size_encoded        5
# source_link                   2
# location_description          2
# event_description             1
# rainfall_7d                   0
# longitude                     0
# latitude                      0
# rainfall_1d                   0
# rainfall_3d                   0
# max_rainfall_7d               0
# rainfall_14d                  0
# gazeteer_closest_point        0
# elevation_m                   0
# slope_deg                     0
# is_rain_triggered             0
# gazeteer_distance             0
# source_name                   0
# admin_division_population     0
# country_code                  0
# country_name                  0
# injury_count                  0
# fatality_count                0
# landslide_setting             0
# landslide_size                0
# landslide_trigger             0
# landslide_category            0
# ...

# %%
df
# Out:
#                 source_name  \
# 0             morungexpress
# 1        The Shillong Times
# 2                 e-pao.net
# 3                   gsi.gov
# 4       www.indiatvnews.com
# ..                      ...
# 346             India times
# 347             Assam Times
# 348          thenewsofindia
# 349               e-pao.net
# 350  The New Indian Express
#
#                                            source_link  event_id  \
# 0        http://www.morungexpress.com/local/56264.html      2587
# 1    http://www.theshillongtimes.com/2015/06/17/ent...      6969
# 2     http://e-pao.net/GP.asp?src=Snipp8..080911.sep11      3965
# 3    http://www.portal.gsi.gov.in/portal/page?_page...      2205
# 4    http://www.indiatvnews.com/news/india/sikkim-l...      4990
# ..                                                 ...       ...
# 346  http://timesofindia.indiatimes.com/India/Flood...       259
# 347               http://www.assamtimes.org/node/11181      6112
# ...

# %%
df.to_csv("NER_landslide_cleaned_full.csv", index=False)
